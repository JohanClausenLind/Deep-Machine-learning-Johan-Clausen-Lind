# %%
import tensorflow as tf
import keras
from keras import layers
import gymnasium as gym
import ale_py
from gymnasium.wrappers.atari_preprocessing import AtariPreprocessing
from gymnasium.wrappers.frame_stack import FrameStack
import numpy as np

gym.register_envs(ale_py)

# %%
env = gym.make("BreakoutNoFrameskip-v4")
env = AtariPreprocessing(env)
env = FrameStack(env, 4)

num_actions = env.action_space.n
trigger = lambda t: t % 20
env = gym.wrappers.RecordVideo(env, video_folder="./videos", episode_trigger=trigger, disable_logger=True)

# %%
def create_q_model():
    return keras.Sequential(
        [
            keras.Input(shape=(84,84,4)),
            layers.Conv2D(32, kernel_size=8, strides=4, activation="relu"),
            layers.Conv2D(64, kernel_size=4, strides=2, activation="relu"),
            layers.Conv2D(64, kernel_size=3, strides=1, activation="relu"),
            layers.Flatten(),
            layers.Dense(512, activation="relu"),
            layers.Dense(num_actions, activation="linear")
        ]
    )

# %%
model = create_q_model()
model_target = create_q_model()

optimizer = keras.optimizers.Adam(learning_rate=.00025, clipnorm=1.0)
# Out:
# /home/raphael/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
action_history = []
state_history = []
state_next_history = []
rewards_history = []
episode_reward_history = []
done_history = []
running_reward = 0
episode_count = 0
frame_count = 0

# %%
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.1
epsilon_max = 1.0
epsilon_interval = epsilon_max - epsilon_min
batch_size = 32

# Maximum episodes to run, set to zero means run till solved
max_episodes = 0
# Max frames to run
max_frames = 1e7

# Number of frames to take random actions and observe output
epsilon_random_frames = 50000
# Number of frames for exploration
epsilon_greedy_frames = 1e6
# Max length of replay buffer
max_memory_length = 1e5
# Abort if more than the below frames are spent in a single game (results in truncated = True)
max_steps_per_episode = 10000
# How often should the action network be updated
update_after_actions = 4
#How often should the Q-network be cloned from our action network?
update_target_network = 10000
# Use Huber loss for stability (specifically for Adam)
loss_function = keras.losses.Huber()

# %%
while True:
    observation, _ = env.reset()
    state = np.array(observation)
    episode_reward = 0

    for timestep in range(1, max_steps_per_episode):
        frame_count += 1

        if frame_count < epsilon_random_frames or epsilon > np.random.rand(1)[0]:
            #Take random action
            action = env.action_space.sample()
        else:
            state_tensor = keras.ops.convert_to_tensor(state)
            state_tensor = keras.ops.transpose([2,3,1])
            state_tensor = keras.ops.expand_dims(state_tensor, 0)
            action_probs = model(state_tensor, training=False)
            #Take best action
            action = keras.ops.argmax(action_probs[0].numpy())
        epsilon -= epsilon_interval / epsilon_greedy_frames
        epsilon = max(epsilon, epsilon_min)

        state_next, reward, done, _, _ = env.step(action)
        state_next = np.array(state_next)

        episode_reward += reward

        action_history.append(action)
        state_history.append(state)
        state_next_history.append(state_next)
        done_history.append(done)
        rewards_history.append(reward)
        state = state_next

        if frame_count % update_after_actions == 0 and len(done_history) > batch_size:
            #Get indices of samples for replay buffers
            indices = np.random.choice(range(len(done_history)), size=batch_size)

            state_sample = np.array([state_history[i] for i in indices])
            state_next_sample = np.array([state_next_history[i] for i in indices])
            rewards_sample = [rewards_history[i] for i in indices]
            action_sample = [action_history[i] for i in indices]
            done_sample = keras.ops.convert_to_tensor([float(done_history[i]) for i in indices])

            future_rewards = model_target.predict(state_next_sample, verbose=0)

            updated_q_values = rewards_sample + gamma * keras.ops.amax(future_rewards, axis=1)

            # If final frame, set the last value to -1 
            updated_q_values = updated_q_values * (1 - done_sample) - done_sample

            # Create a mask so we can calculate loss
            masks = keras.ops.one_hot(action_sample, num_actions)

            with tf.GradientTape() as tape:
                #Train the model on the states
                q_values = model(state_sample)
                q_action = keras.ops.sum(keras.ops.multiply(q_values, masks), axis=1)
                loss = loss_function(updated_q_values, q_action)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
        if frame_count % update_target_network == 0:
            model_target.set_weights(model.get_weights())
            print(f"best scroe of last 100: {np.max(episode_reward_history)}, running_reward{running_reward} at episode {episode_count}, frame {frame_count}")
            model.save(f"breakout_qmodel_{episode_count}.keras") 

        if len(rewards_history)>max_memory_length:
            del rewards_history[:1]
            del state_history[:1]
            del state_next_history[:1]
            del action_history[:1]
            del done_history[:1]

        if done:                     
            break
    episode_reward_history.append(episode_reward)
    if len(episode_reward_history) > 100:
        del episode_reward_history[:1]
    running_reward = np.mean(episode_reward_history)

    episode_count += 1

    if running_reward > 40:
        print("Solved at episode {episode_count}!")
        model.save(f"breakout_qmodel_solved.keras")
        break

    if (max_episodes > 0 and episode_count >= max_episodes):
         print("Stopped at episode {episode_count}!")
         break
    if (max_frames > 0 and frame_count>=max_frames):
        print(f"Stopped at frame {frame_count}!")
        break
# Out:
# best scroe of last 100: 5.0, running_reward1.6666666666666667 at episode 48, frame 10000
# best scroe of last 100: 5.0, running_reward1.44 at episode 103, frame 20000
# best scroe of last 100: 9.0, running_reward1.26 at episode 155, frame 30000
# best scroe of last 100: 5.0, running_reward1.06 at episode 214, frame 40000
# best scroe of last 100: 10.0, running_reward1.2 at episode 265, frame 50000
# best scroe of last 100: 10.0, running_reward1.34 at episode 320, frame 60000
# best scroe of last 100: 6.0, running_reward1.27 at episode 373, frame 70000
# best scroe of last 100: 6.0, running_reward1.15 at episode 430, frame 80000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 59
#      57         loss = loss_function(updated_q_values, q_action)
#      58     grads = tape.gradient(loss, model.trainable_variables)
# ---> 59     optimizer.apply_gradients(zip(grads, model.trainable_variables))
#      60 if frame_count % update_target_network == 0:
#      61     model_target.set_weights(model.get_weights())
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:344, in BaseOptimizer.apply_gradients(self, grads_and_vars)
#     342 def apply_gradients(self, grads_and_vars):
#     343     grads, trainable_variables = zip(*grads_and_vars)
# --> 344     self.apply(grads, trainable_variables)
#     345     # Return iterations for compat with tf.keras.
#     346     return self._iterations
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:409, in BaseOptimizer.apply(self, grads, trainable_variables)
#     406     grads = [g if g is None else g / scale for g in grads]
#     408 # Apply gradient updates.
# --> 409 self._backend_apply_gradients(grads, trainable_variables)
#     410 # Apply variable constraints after applying gradients.
#     411 for variable in trainable_variables:
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:472, in BaseOptimizer._backend_apply_gradients(self, grads, trainable_variables)
#     469     self._apply_weight_decay(trainable_variables)
#     471     # Run udpate step.
# --> 472     self._backend_update_step(
#     473         grads, trainable_variables, self.learning_rate
#     474     )
#     476 if self.use_ema:
#     477     self._update_model_variables_moving_average(
#     478         self._trainable_variables
#     479     )
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py:122, in TFOptimizer._backend_update_step(self, grads, trainable_variables, learning_rate)
#     120 grads_and_vars = list(zip(grads, trainable_variables))
#     121 grads_and_vars = self._all_reduce_sum_gradients(grads_and_vars)
# --> 122 tf.__internal__.distribute.interim.maybe_merge_call(
#     123     self._distributed_tf_update_step,
#     124     self._distribution_strategy,
#     125     grads_and_vars,
#     126     learning_rate,
#     127 )
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py:136, in TFOptimizer._distributed_tf_update_step(self, distribution, grads_and_vars, learning_rate)
#     133     return self.update_step(grad, var, learning_rate)
#     135 for grad, var in grads_and_vars:
# --> 136     distribution.extended.update(
#     137         var,
#     138         apply_grad_to_update_var,
#     139         args=(grad, learning_rate),
#     140         group=False,
#     141     )
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:3005, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3002   fn = autograph.tf_convert(
#    3003       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3004   with self._container_strategy().scope():
# -> 3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
#    3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:4075, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4072 def _update(self, var, fn, args, kwargs, group):
#    4073   # The implementations of _update() and _update_non_slot() are identical
#    4074   # except _update() passes `var` as the first argument to `fn()`.
# -> 4075   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:4081, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4077 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4078   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4079   # once that value is used for something.
#    4080   with UpdateContext(colocate_with):
# -> 4081     result = fn(*args, **kwargs)
#    4082     if should_group:
#    4083       return result
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:596, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     594 def wrapper(*args, **kwargs):
#     595   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596     return func(*args, **kwargs)
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py:133, in TFOptimizer._distributed_tf_update_step.<locals>.apply_grad_to_update_var(var, grad, learning_rate)
#     132 def apply_grad_to_update_var(var, grad, learning_rate):
# --> 133     return self.update_step(grad, var, learning_rate)
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/optimizers/adam.py:124, in Adam.update_step(self, gradient, variable, learning_rate)
#     119 local_step = ops.cast(self.iterations + 1, variable.dtype)
#     120 beta_1_power = ops.power(
#     121     ops.cast(self.beta_1, variable.dtype), local_step
#     122 )
#     123 beta_2_power = ops.power(
# --> 124     ops.cast(self.beta_2, variable.dtype), local_step
#     125 )
#     127 m = self._momentums[self._get_variable_index(variable)]
#     128 v = self._velocities[self._get_variable_index(variable)]
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/ops/core.py:800, in cast(x, dtype)
#     784 """Cast a tensor to the desired dtype.
#     785
#     786 Args:
#    (...)
#     796 >>> x = keras.ops.cast(x, dtype="float16")
#     797 """
#     798 dtype = backend.standardize_dtype(dtype)
# --> 800 if any_symbolic_tensors((x,)):
#     801     return Cast(dtype=dtype)(x)
#     802 return backend.core.cast(x, dtype)
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/backend/common/keras_tensor.py:349, in any_symbolic_tensors(args, kwargs)
#     347 args = args or ()
#     348 kwargs = kwargs or {}
# --> 349 for x in tree.flatten((args, kwargs)):
#     350     if isinstance(x, KerasTensor):
#     351         return True
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/tree/tree_api.py:121, in flatten(structure)
#      91 @keras_export("keras.tree.flatten")
#      92 def flatten(structure):
#      93     """Flattens a possibly nested structure into a list.
#      94
#      95     In the case of dict instances, the sequence consists of the values,
#    (...)
#     119         A list, the flattened version of the input `structure`.
#     120     """
# --> 121     return tree_impl.flatten(structure)
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/keras/src/tree/optree_impl.py:66, in flatten(structure)
#      62 def flatten(structure):
#      63     # optree.tree_flatten returns a pair (leaves, treespec) where the first
#      64     # element is a list of leaf values and the second element is a treespec
#      65     # representing the structure of the pytree.
# ---> 66     leaves, _ = optree.tree_flatten(
#      67         structure, none_is_leaf=True, namespace="keras"
#      68     )
#      69     return leaves
#
# File ~/ITHS/AI23/AI23-Deep-Learning/.venv/lib/python3.12/site-packages/optree/ops.py:192, in tree_flatten(tree, is_leaf, none_is_leaf, namespace)
#     127 def tree_flatten(
#     128     tree: PyTree[T],
#     129     is_leaf: Callable[[T], bool] | None = None,
#    (...)
#     132     namespace: str = '',
#     133 ) -> tuple[list[T], PyTreeSpec]:
#     134     """Flatten a pytree.
#     135
#     136     See also :func:`tree_flatten_with_path` and :func:`tree_unflatten`.
#    (...)
#     190         second element is a treespec representing the structure of the pytree.
#     191     """
# --> 192     return _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#
# KeyboardInterrupt:
